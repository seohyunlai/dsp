# %% [markdown]
# 1-3
# Synthesize a compound signal by creating SinSignal and CosSignal objects and adding them up. Evaluate the signal to get a Wave, and listen to it. Compute its Spectrum and plot it. What happens if you add frequency components that are not multiples of the fundamental?
# 通過創建SinSignal和CosSignal對象並將它們加起來來合成複合信號。評估信號以獲得Wave，然後聆聽。計算其頻譜並繪製。如果添加的頻率分量不是基頻的倍數，會發生什麼？

# %% [markdown]
# freq 是頻率，單位 Hz。amp 是振幅，數字代表錄到或播放的最大振幅。

# %%
from thinkdsp import SinSignal
from thinkdsp import CosSignal

signal = (SinSignal(freq=300, amp=1.0) +
          CosSignal(freq=400, amp=0.5) +
          SinSignal(freq=500, amp=0.25))
signal.plot()

# %%
wave2 = signal.make_wave(duration=1)
wave2.apodize()
wave2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 頻譜

# %%
spectrum = wave2.make_spectrum()
spectrum.plot(high=1000)

# %% [markdown]
# 倍數是100，所以這邊用314跟9，發現如果不是100的倍數，會聽到不同的音調。

# %%
signal =signal+ SinSignal(freq=314)+CosSignal(freq=9)
signal.make_wave().make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
