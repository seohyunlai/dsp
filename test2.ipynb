# %%
import numpy as np
import matplotlib.pyplot as plt

from thinkdsp import decorate

# %% [markdown]
# 2.1

# %%
from thinkdsp import UncorrelatedGaussianNoise

signal = UncorrelatedGaussianNoise()
x = signal.make_wave(duration=1,framerate=10000) # 持續一秒，每秒10000點
x.ys.shape
# Out:
# (10000,)

# %% [markdown]
# 2.2

# %%
x.plot() # 畫出波形圖

# %% [markdown]
# 最大值為：4。平均值：0。

# %% [markdown]
# 2.3

# %%
sx = x.make_spectrum() # 先畫頻譜圖
sx.plot()

# %%
sx.hs.shape
# Out:
# (5001,)

# %% [markdown]
# 2.4

# %%
integ = sx.make_integrated_spectrum()
integ.plot_power()

# %% [markdown]
# 2.5

# %%
integ = sx.make_integrated_spectrum()
integ.plot_power()
loglog = dict(xscale='log', yscale='log') # 取log-scale
decorate( **loglog)

# %% [markdown]
# 2.6

# %%
sx.estimate_slope().slope
# Out:
# 0.01692384040961581

# %% [markdown]
# 2.7

# %%
def cumsum(self): 
       
        ys = np.cumsum(self.ys)
        ts = self.ts.copy()
        return Wave(ys, ts, self.framerate)

# %%
y= x.cumsum()
y.plot() # 畫出wave

# %% [markdown]
# 2-8

# %%
sx1= y.make_spectrum() # 先畫頻譜圖
integ1 = sx1.make_integrated_spectrum()
integ1.plot_power()
loglog = dict(xscale='log', yscale='log') # 取log-scale，方便觀察
decorate( **loglog)

# %%
sx1.estimate_slope().slope
# Out:
# -1.7897049315826186

# %% [markdown]
# 2-9

# %%
from thinkdsp import BrownianNoise

signa2 = BrownianNoise()
z= signa2.make_wave(duration=1, framerate=10000)
z.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sx2 = z.make_spectrum() # 先畫頻譜圖
sx2.plot()

# %%
integ2 = sx2.make_integrated_spectrum()
integ2.plot_power()
loglog = dict(xscale='log', yscale='log') # 取log-scale
decorate( **loglog)

# %%
sx2.estimate_slope().slope
# Out:
# -1.7994996753469157

# %% [markdown]
# 2-10

# %% [markdown]
# 斜率為-1.7，跟y比較相近，y也是大約為-1.7。
